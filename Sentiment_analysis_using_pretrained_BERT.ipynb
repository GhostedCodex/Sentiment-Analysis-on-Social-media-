# %% [markdown]
# ## Using a pretrained Bert model

# %%
! pip install transformers torch
# Out:
# Requirement already satisfied: transformers in c:\users\humaidu\anaconda3\lib\site-packages (4.57.1)
# Requirement already satisfied: torch in c:\users\humaidu\anaconda3\lib\site-packages (2.9.0)
# Requirement already satisfied: filelock in c:\users\humaidu\anaconda3\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\humaidu\anaconda3\lib\site-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\humaidu\anaconda3\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\humaidu\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\humaidu\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\humaidu\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\humaidu\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\humaidu\anaconda3\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\humaidu\anaconda3\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\humaidu\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\humaidu\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\humaidu\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\humaidu\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\humaidu\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\humaidu\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\humaidu\anaconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\humaidu\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\humaidu\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\humaidu\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\humaidu\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\humaidu\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\humaidu\anaconda3\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\humaidu\anaconda3\lib\site-packages (from requests->transformers) (2025.10.5)

# %%
from transformers import pipeline

# %%
# Initialize the sentiment-analysis pipeline
# This downloads a default model (distilbert-base-uncased-finetuned-sst-2-english)
sentiment_pipeline = pipeline("sentiment-analysis",
                             model="distilbert/distilbert-base-uncased-finetuned-sst-2-english",)

# Testing
data = [
    "The flight was amazing and the staff was helpful!",
    "I lost my luggage and the service was terrible.",
    "The food was okay, but the seat was uncomfortable." # BERT handles nuance better
]

results = sentiment_pipeline(data)
#printing results
for text, result in zip(data, results):
    print(f"Text: {text}")
    print(f"Label: {result['label']}, Score: {result['score']:.4f}\n")
# Out:
# Device set to use cpu
# Text: The flight was amazing and the staff was helpful!
# Label: POSITIVE, Score: 0.9999
#
# Text: I lost my luggage and the service was terrible.
# Label: NEGATIVE, Score: 0.9997
#
# Text: The food was okay, but the seat was uncomfortable.
# Label: NEGATIVE, Score: 0.9920
